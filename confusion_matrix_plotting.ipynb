# %% [markdown]
# <a href="https://colab.research.google.com/github/umar-faroooq/Machine-learning/blob/main/confusion_matrix_plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = [[242,14], [22,158]]
df_cm = pd.DataFrame(array, index = [i for i in "12"],
                  columns = [i for i in "12"])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap='Blues', fmt='g')
#Simple Perceptron with tfidf

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

array = [[2326, 17, 5, 17], [22, 3171, 43, 30], [13, 225, 694, 25], [21, 4, 2, 996]]
df_cm = pd.DataFrame(array, index = [i for i in "1234"],
                  columns = [i for i in "1234"])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap='Blues',  fmt='g')
#Random Forest with tfidf with tfidf
